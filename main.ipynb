# %% [markdown]
# # Pipeline PDI Catarata
# Executa os scripts em ordem: preprocessing → find_circles → build_videos

# %%
# !python src/preprocessing.py

# %%
# !python src/find_circles_v2.py

# %%
# !python src/build_videos.py
